# %% [markdown]
# <a href="https://colab.research.google.com/github/Zaiddc/Thesis_ML_Metal_Complexes/blob/main/Deep_Learning_for_Real_Estate_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES AND DATASETS
#
# > Indented block

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt



# setting the style of the notebook to be monokai theme  
# this line of code is important to ensure that we are able to see the x and y axes clearly
# If you don't run this code line, you will notice that the xlabel and ylabel on any plot is black on black and it will be hard to see them.

# %%
house_df = pd.read_csv('realestate_prices.csv', encoding = 'ISO-8859-1')

# %%
house_df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
house_df.tail(5)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [5 rows x 21 columns]

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# **PRACTICE OPPORTUNITY #1 [OPTIONAL]:**
# - **What is the average house price?**
# - **What is the price of the cheapest house?**
# - **What is the average number of bathrooms and bedrooms? round your answer to the lowest value**
# - **What is the maximum number of bedrooms?**

# %%
house_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
#  PERFORM DATA VISUALIZATION

# %%
sns.scatterplot(x= 'sqft_living', y ='price', data = house_df)

# %%
house_df.hist(bins = 20, figsize=(20,20), color = 'b')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf3d3e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf38c4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf343ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf308110>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf2be710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf275d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf23a3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf1f1910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf1f1950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf1b4090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf122b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf0e71d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf09c7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf0d3dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf098410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf04ca10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbf005fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbefc9650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbef80c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1cbef44290>]],
#       dtype=object)

# %%
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(house_df.corr(), annot = True)

# %%
house_df_sample = house_df[ ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement', 'yr_built']   ]

# %%
house_df_sample
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  sqft_above  \
# 0      221900.0         3       1.00         1180      5650        1180
# 1      538000.0         3       2.25         2570      7242        2170
# 2      180000.0         2       1.00          770     10000         770
# 3      604000.0         4       3.00         1960      5000        1050
# 4      510000.0         3       2.00         1680      8080        1680
# ...         ...       ...        ...          ...       ...         ...
# 21608  360000.0         3       2.50         1530      1131        1530
# 21609  400000.0         4       2.50         2310      5813        2310
# 21610  402101.0         2       0.75         1020      1350        1020
# 21611  400000.0         3       2.50         1600      2388        1600
# 21612  325000.0         2       0.75         1020      1076        1020
#
#        sqft_basement  yr_built
# 0                  0      1955
# 1                400      1951
# 2                  0      1933
# 3                910      1965
# 4                  0      1987
# ...              ...       ...
# 21608              0      2009
# 21609              0      2014
# 21610              0      2009
# 21611              0      2004
# 21612              0      2008
#
# [21613 rows x 8 columns]

# %% [markdown]
# - **Using Seaborn, plot the pairplot for the features contained in "house_df_sample"**
# - **Explore the data and perform sanity check**

# %%
sns.pairplot(house_df_sample)

# %% [markdown]
#  PERFORM DATA CLEANING AND FEATURE ENGINEERING

# %%
selected_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement']

# %%
X = house_df[selected_features]

# %%
X #Check the MinMaxScaler
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  sqft_above  \
# 0             3       1.00         1180      5650     1.0        1180
# 1             3       2.25         2570      7242     2.0        2170
# 2             2       1.00          770     10000     1.0         770
# 3             4       3.00         1960      5000     1.0        1050
# 4             3       2.00         1680      8080     1.0        1680
# ...         ...        ...          ...       ...     ...         ...
# 21608         3       2.50         1530      1131     3.0        1530
# 21609         4       2.50         2310      5813     2.0        2310
# 21610         2       0.75         1020      1350     2.0        1020
# 21611         3       2.50         1600      2388     2.0        1600
# 21612         2       0.75         1020      1076     2.0        1020
#
#        sqft_basement
# 0                  0
# 1                400
# 2                  0
# 3                910
# 4                  0
# ...              ...
# 21608              0
# 21609              0
# 21610              0
# 21611              0
# 21612              0
#
# [21613 rows x 7 columns]

# %%
y = house_df['price']

# %%
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
X.shape
# Out:
# (21613, 7)

# %%
y.shape
# Out:
# (21613,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()  .
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.09090909, 0.125     , 0.06716981, ..., 0.        , 0.09758772,
#         0.        ],
#        [0.09090909, 0.28125   , 0.17207547, ..., 0.4       , 0.20614035,
#         0.08298755],
#        [0.06060606, 0.125     , 0.03622642, ..., 0.        , 0.05263158,
#         0.        ],
#        ...,
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.4       , 0.08004386,
#         0.        ],
#        [0.09090909, 0.3125    , 0.09886792, ..., 0.4       , 0.14364035,
#         0.        ],
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.4       , 0.08004386,
#         0.        ]])

# %%
X_scaled.shape
# Out:
# (21613, 7)

# %%
scaler.data_max_
# Out:
# array([3.300000e+01, 8.000000e+00, 1.354000e+04, 1.651359e+06,
#        3.500000e+00, 9.410000e+03, 4.820000e+03])

# %%
scaler.data_min_
# Out:
# array([  0.,   0., 290., 520.,   1., 290.,   0.])

# %%
y = y.values.reshape(-1,1)

# %%
y_scaled = scaler.fit_transform(y)

# %%
y_scaled
# Out:
# array([[0.01926557],
#        [0.06072131],
#        [0.01377049],
#        ...,
#        [0.04289849],
#        [0.04262295],
#        [0.03278689]])

# %% [markdown]
#  TRAIN A DEEP LEARNING MODEL WITH LIMITED NUMBER OF FEATURES

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y_scaled, test_size=0.25)

# %%
X_train.shape
# Out:
# (16209, 7)

# %%
X_test.shape
# Out:
# (5404, 7)

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(100,input_dim = 7, activation = 'relu'))
model.add(Dense(100, activation = 'relu'))
model.add(Dense(100, activation = 'relu'))
model.add(Dense(200, activation = 'relu'))
model.add(Dense(1,activation ='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               800
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 200)               20200
#
#  dense_4 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 41,401
# Trainable params: 41,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'Adam', loss = 'mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100, batch_size = 50, validation_split = 0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 2s 4ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 2/100
# 260/260 [==============================] - 1s 4ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 3/100
# 260/260 [==============================] - 1s 4ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 4/100
# 260/260 [==============================] - 1s 4ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 5/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.8739e-04 - val_loss: 9.7822e-04
# Epoch 6/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.8420e-04 - val_loss: 9.8376e-04
# Epoch 7/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.6425e-04 - val_loss: 0.0013
# Epoch 8/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.7436e-04 - val_loss: 0.0012
# Epoch 9/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.8275e-04 - val_loss: 0.0010
# Epoch 10/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.5752e-04 - val_loss: 0.0011
# Epoch 11/100
# 260/260 [==============================] - 2s 6ms/step - loss: 9.5556e-04 - val_loss: 0.0010
# Epoch 12/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.4192e-04 - val_loss: 0.0011
# Epoch 13/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.5128e-04 - val_loss: 0.0011
# Epoch 14/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.4307e-04 - val_loss: 0.0012
# Epoch 15/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.4476e-04 - val_loss: 0.0012
# Epoch 16/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.5487e-04 - val_loss: 9.9797e-04
# Epoch 17/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.3190e-04 - val_loss: 0.0011
# Epoch 18/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.2952e-04 - val_loss: 0.0011
# Epoch 19/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.3349e-04 - val_loss: 0.0011
# Epoch 20/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.3677e-04 - val_loss: 9.8287e-04
# Epoch 21/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.4400e-04 - val_loss: 0.0011
# Epoch 22/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.2060e-04 - val_loss: 0.0011
# Epoch 23/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.1119e-04 - val_loss: 0.0010
# Epoch 24/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.1720e-04 - val_loss: 0.0012
# Epoch 25/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.3892e-04 - val_loss: 0.0010
# Epoch 26/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.6544e-04 - val_loss: 0.0010
# Epoch 27/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.1940e-04 - val_loss: 9.8693e-04
# Epoch 28/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.0465e-04 - val_loss: 9.8473e-04
# Epoch 29/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.2128e-04 - val_loss: 0.0011
# Epoch 30/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.2162e-04 - val_loss: 0.0010
# Epoch 31/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.1737e-04 - val_loss: 0.0010
# Epoch 32/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.0683e-04 - val_loss: 0.0010
# Epoch 33/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.1358e-04 - val_loss: 0.0010
# Epoch 34/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.0713e-04 - val_loss: 0.0010
# Epoch 35/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.0077e-04 - val_loss: 0.0011
# Epoch 36/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.1181e-04 - val_loss: 0.0012
# Epoch 37/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.9700e-04 - val_loss: 0.0010
# Epoch 38/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.1175e-04 - val_loss: 0.0011
# Epoch 39/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.9944e-04 - val_loss: 0.0011
# Epoch 40/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.9851e-04 - val_loss: 9.9513e-04
# Epoch 41/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.9877e-04 - val_loss: 0.0011
# Epoch 42/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.9862e-04 - val_loss: 0.0011
# Epoch 43/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.0322e-04 - val_loss: 0.0010
# Epoch 44/100
# 260/260 [==============================] - 1s 5ms/step - loss: 8.9917e-04 - val_loss: 9.8115e-04
# Epoch 45/100
# 260/260 [==============================] - 2s 7ms/step - loss: 8.8800e-04 - val_loss: 0.0010
# Epoch 46/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.8744e-04 - val_loss: 9.6404e-04
# Epoch 47/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.8637e-04 - val_loss: 0.0011
# Epoch 48/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.9610e-04 - val_loss: 9.9252e-04
# Epoch 49/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.8364e-04 - val_loss: 0.0010
# Epoch 50/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.8159e-04 - val_loss: 0.0011
# Epoch 51/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.9785e-04 - val_loss: 0.0011
# Epoch 52/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.7329e-04 - val_loss: 9.8918e-04
# Epoch 53/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.8402e-04 - val_loss: 9.9826e-04
# Epoch 54/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.8043e-04 - val_loss: 9.7986e-04
# Epoch 55/100
# 260/260 [==============================] - 1s 5ms/step - loss: 8.8076e-04 - val_loss: 0.0010
# Epoch 56/100
# 260/260 [==============================] - 2s 8ms/step - loss: 8.7970e-04 - val_loss: 9.7471e-04
# Epoch 57/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.6689e-04 - val_loss: 0.0010
# Epoch 58/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.7121e-04 - val_loss: 9.7776e-04
# Epoch 59/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.6579e-04 - val_loss: 0.0010
# Epoch 60/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.8086e-04 - val_loss: 0.0011
# Epoch 61/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.7560e-04 - val_loss: 9.6502e-04
# Epoch 62/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.6710e-04 - val_loss: 0.0010
# Epoch 63/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.6252e-04 - val_loss: 0.0010
# Epoch 64/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.7076e-04 - val_loss: 0.0010
# Epoch 65/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.6361e-04 - val_loss: 0.0011
# Epoch 66/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.7187e-04 - val_loss: 0.0011
# Epoch 67/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.5710e-04 - val_loss: 0.0010
# Epoch 68/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.7294e-04 - val_loss: 9.8725e-04
# Epoch 69/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.5834e-04 - val_loss: 0.0010
# Epoch 70/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.5261e-04 - val_loss: 9.5482e-04
# Epoch 71/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.5997e-04 - val_loss: 0.0010
# Epoch 72/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.5731e-04 - val_loss: 9.9702e-04
# Epoch 73/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.4749e-04 - val_loss: 9.7247e-04
# Epoch 74/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.5477e-04 - val_loss: 0.0010
# Epoch 75/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.5253e-04 - val_loss: 0.0010
# Epoch 76/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.4811e-04 - val_loss: 9.8689e-04
# Epoch 77/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.4427e-04 - val_loss: 9.7154e-04
# Epoch 78/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.4902e-04 - val_loss: 9.9112e-04
# Epoch 79/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.5055e-04 - val_loss: 9.8594e-04
# Epoch 80/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.4717e-04 - val_loss: 9.8358e-04
# Epoch 81/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.4471e-04 - val_loss: 9.7676e-04
# Epoch 82/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.4248e-04 - val_loss: 0.0010
# Epoch 83/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.3856e-04 - val_loss: 0.0010
# Epoch 84/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.4057e-04 - val_loss: 0.0011
# Epoch 85/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.4325e-04 - val_loss: 0.0010
# Epoch 86/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.4460e-04 - val_loss: 0.0010
# Epoch 87/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.4813e-04 - val_loss: 0.0010
# Epoch 88/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.4589e-04 - val_loss: 0.0010
# Epoch 89/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.3777e-04 - val_loss: 9.7008e-04
# Epoch 90/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.3467e-04 - val_loss: 0.0010
# Epoch 91/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.3903e-04 - val_loss: 0.0012
# Epoch 92/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.3441e-04 - val_loss: 0.0010
# Epoch 93/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.2938e-04 - val_loss: 0.0010
# Epoch 94/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.3589e-04 - val_loss: 0.0010
# Epoch 95/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.3627e-04 - val_loss: 0.0011
# Epoch 96/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.3852e-04 - val_loss: 9.8329e-04
# Epoch 97/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.2774e-04 - val_loss: 9.9282e-04
# Epoch 98/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.2383e-04 - val_loss: 9.9298e-04
# Epoch 99/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.2176e-04 - val_loss: 9.8668e-04
# Epoch 100/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.3033e-04 - val_loss: 9.9165e-04

# %% [markdown]
#  EVALUATE TRAINED DEEP LEARNING MODEL PERFORMANCE

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
# 'bedrooms','bathrooms','sqft_living','sqft_lot','floors', 'sqft_above', 'sqft_basement'
X_test_1 = np.array([[ 4, 3, 1960, 5000, 1, 2000, 3000 ]])

scaler_1 = MinMaxScaler()
X_test_scaled_1 = scaler_1.fit_transform(X_test_1)

y_predict_1 = model.predict(X_test_scaled_1)

y_predict_1 = scaler.inverse_transform(y_predict_1)
y_predict_1
# Out:
# 1/1 [==============================] - 0s 104ms/step
# array([[268161.66]], dtype=float32)

# %%
y_predict = model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# 169/169 [==============================] - 0s 2ms/step
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig = scaler.inverse_transform(y_predict)
y_test_orig = scaler.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
plt.xlim(0, 5000000)
plt.ylim(0, 3000000)
# Out:
# (0.0, 3000000.0)

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 5404

# %%
k
# Out:
# 7

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 243667.113
# MSE = 59373661932.67197
# MAE = 151903.96244969004
# R2 = 0.5560751559894472
# Adjusted R2 = 0.555499271277054

# %% [markdown]
#  TRAIN AND EVALUATE A DEEP LEARNING MODEL WITH INCREASED NUMBER OF FEATURES (INDEPENDANT VARIABLES)

# %%
selected_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors', 'sqft_above', 'sqft_basement', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'yr_built', 
'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

X = house_df[selected_features]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
y = house_df['price']

# %%
y = y.values.reshape(-1,1)
y_scaled = scaler.fit_transform(y)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(10, input_dim = 19, activation = 'relu'))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(1, activation = 'linear')) # Try using Relu

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100, batch_size = 50, verbose = 1, validation_split = 0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 2/100
# 260/260 [==============================] - 1s 3ms/step - loss: 7.8710e-04 - val_loss: 8.3651e-04
# Epoch 3/100
# 260/260 [==============================] - 1s 3ms/step - loss: 6.6369e-04 - val_loss: 7.6660e-04
# Epoch 4/100
# 260/260 [==============================] - 1s 3ms/step - loss: 6.1338e-04 - val_loss: 6.8777e-04
# Epoch 5/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.7474e-04 - val_loss: 6.7137e-04
# Epoch 6/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.4798e-04 - val_loss: 6.2921e-04
# Epoch 7/100
# 260/260 [==============================] - 1s 3ms/step - loss: 5.3069e-04 - val_loss: 6.3331e-04
# Epoch 8/100
# 260/260 [==============================] - 1s 3ms/step - loss: 5.1053e-04 - val_loss: 5.9443e-04
# Epoch 9/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.0340e-04 - val_loss: 6.1761e-04
# Epoch 10/100
# 260/260 [==============================] - 1s 3ms/step - loss: 4.9749e-04 - val_loss: 5.8156e-04
# Epoch 11/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.8551e-04 - val_loss: 5.6446e-04
# Epoch 12/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.7520e-04 - val_loss: 5.5690e-04
# Epoch 13/100
# 260/260 [==============================] - 1s 3ms/step - loss: 4.7367e-04 - val_loss: 5.5178e-04
# Epoch 14/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.6021e-04 - val_loss: 5.4946e-04
# Epoch 15/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.5616e-04 - val_loss: 5.2372e-04
# Epoch 16/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.4693e-04 - val_loss: 5.2733e-04
# Epoch 17/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.4008e-04 - val_loss: 5.2134e-04
# Epoch 18/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.3086e-04 - val_loss: 5.0232e-04
# Epoch 19/100
# 260/260 [==============================] - 1s 3ms/step - loss: 4.2711e-04 - val_loss: 5.0477e-04
# Epoch 20/100
# 260/260 [==============================] - 1s 3ms/step - loss: 4.2090e-04 - val_loss: 4.9155e-04
# Epoch 21/100
# 260/260 [==============================] - 1s 3ms/step - loss: 4.2050e-04 - val_loss: 4.8438e-04
# Epoch 22/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.1020e-04 - val_loss: 5.0505e-04
# Epoch 23/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.9645e-04 - val_loss: 4.7461e-04
# Epoch 24/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.9196e-04 - val_loss: 4.5849e-04
# Epoch 25/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.8817e-04 - val_loss: 4.5177e-04
# Epoch 26/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.8080e-04 - val_loss: 4.5108e-04
# Epoch 27/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.7833e-04 - val_loss: 4.7283e-04
# Epoch 28/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.7538e-04 - val_loss: 4.3412e-04
# Epoch 29/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.6958e-04 - val_loss: 4.4604e-04
# Epoch 30/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.6870e-04 - val_loss: 4.3653e-04
# Epoch 31/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.6455e-04 - val_loss: 4.2956e-04
# Epoch 32/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.6187e-04 - val_loss: 4.1753e-04
# Epoch 33/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.6272e-04 - val_loss: 4.2536e-04
# Epoch 34/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.5181e-04 - val_loss: 4.0935e-04
# Epoch 35/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.5465e-04 - val_loss: 4.4134e-04
# Epoch 36/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4944e-04 - val_loss: 4.1560e-04
# Epoch 37/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.5021e-04 - val_loss: 4.2864e-04
# Epoch 38/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.4584e-04 - val_loss: 4.0794e-04
# Epoch 39/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4574e-04 - val_loss: 4.1558e-04
# Epoch 40/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4523e-04 - val_loss: 4.1206e-04
# Epoch 41/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4704e-04 - val_loss: 4.1311e-04
# Epoch 42/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4031e-04 - val_loss: 3.9023e-04
# Epoch 43/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.3946e-04 - val_loss: 4.0750e-04
# Epoch 44/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.3856e-04 - val_loss: 4.2534e-04
# Epoch 45/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.3704e-04 - val_loss: 3.9395e-04
# Epoch 46/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.3834e-04 - val_loss: 4.1454e-04
# Epoch 47/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.3725e-04 - val_loss: 3.7579e-04
# Epoch 48/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.2999e-04 - val_loss: 3.7234e-04
# Epoch 49/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.2867e-04 - val_loss: 3.7256e-04
# Epoch 50/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.3176e-04 - val_loss: 3.9375e-04
# Epoch 51/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.2736e-04 - val_loss: 3.8351e-04
# Epoch 52/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.2711e-04 - val_loss: 3.6769e-04
# Epoch 53/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.2671e-04 - val_loss: 3.8088e-04
# Epoch 54/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.2811e-04 - val_loss: 3.7481e-04
# Epoch 55/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.2451e-04 - val_loss: 4.0252e-04
# Epoch 56/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.2692e-04 - val_loss: 3.7365e-04
# Epoch 57/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.2015e-04 - val_loss: 4.0143e-04
# Epoch 58/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.2331e-04 - val_loss: 3.7716e-04
# Epoch 59/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.2193e-04 - val_loss: 3.6544e-04
# Epoch 60/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.1873e-04 - val_loss: 3.7985e-04
# Epoch 61/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.1609e-04 - val_loss: 3.9230e-04
# Epoch 62/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.1573e-04 - val_loss: 3.7807e-04
# Epoch 63/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.2144e-04 - val_loss: 3.6687e-04
# Epoch 64/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.1925e-04 - val_loss: 3.6978e-04
# Epoch 65/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.1750e-04 - val_loss: 3.8128e-04
# Epoch 66/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.1670e-04 - val_loss: 3.5553e-04
# Epoch 67/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.1777e-04 - val_loss: 3.6823e-04
# Epoch 68/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.1629e-04 - val_loss: 3.5839e-04
# Epoch 69/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.1311e-04 - val_loss: 3.7655e-04
# Epoch 70/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.1663e-04 - val_loss: 3.6418e-04
# Epoch 71/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.1528e-04 - val_loss: 3.6739e-04
# Epoch 72/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.1428e-04 - val_loss: 3.6010e-04
# Epoch 73/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.1338e-04 - val_loss: 3.5646e-04
# Epoch 74/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.0948e-04 - val_loss: 3.5936e-04
# Epoch 75/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.1825e-04 - val_loss: 3.6224e-04
# Epoch 76/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.1665e-04 - val_loss: 3.8298e-04
# Epoch 77/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.1299e-04 - val_loss: 3.5393e-04
# Epoch 78/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.0786e-04 - val_loss: 3.6460e-04
# Epoch 79/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.1714e-04 - val_loss: 3.6608e-04
# Epoch 80/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.0911e-04 - val_loss: 3.5321e-04
# Epoch 81/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.1263e-04 - val_loss: 3.9870e-04
# Epoch 82/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.0963e-04 - val_loss: 3.7249e-04
# Epoch 83/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.0886e-04 - val_loss: 3.6033e-04
# Epoch 84/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.0839e-04 - val_loss: 3.8484e-04
# Epoch 85/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.0370e-04 - val_loss: 3.7706e-04
# Epoch 86/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.0911e-04 - val_loss: 3.6082e-04
# Epoch 87/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.1021e-04 - val_loss: 3.6968e-04
# Epoch 88/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.0789e-04 - val_loss: 3.5020e-04
# Epoch 89/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.1127e-04 - val_loss: 3.6034e-04
# Epoch 90/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.0446e-04 - val_loss: 3.6483e-04
# Epoch 91/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.0766e-04 - val_loss: 3.6572e-04
# Epoch 92/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.1479e-04 - val_loss: 3.5921e-04
# Epoch 93/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.1486e-04 - val_loss: 3.7180e-04
# Epoch 94/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.0557e-04 - val_loss: 3.5147e-04
# Epoch 95/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.0578e-04 - val_loss: 3.7586e-04
# Epoch 96/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.0382e-04 - val_loss: 3.5773e-04
# Epoch 97/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.0374e-04 - val_loss: 3.4672e-04
# Epoch 98/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.0627e-04 - val_loss: 3.6824e-04
# Epoch 99/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.0625e-04 - val_loss: 3.6060e-04
# Epoch 100/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.0650e-04 - val_loss: 3.5232e-04

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.ylabel('Training and Validation Loss')
plt.xlabel('Epoch number')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
y_predict = model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel("Model Predictions")
plt.ylabel("True Value (ground Truth)")
plt.title('Linear Regression Predictions')
plt.show()
# Out:
# 169/169 [==============================] - 0s 2ms/step

# %%
y_predict_orig = scaler.inverse_transform(y_predict)
y_test_orig = scaler.inverse_transform(y_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 147286.609
# MSE = 21693345209.178192
# MAE = 85131.71656990192
# R2 = 0.8471082252292009
# Adjusted R2 = 0.8469098852693426

# %% [markdown]
# - **What is the average house price?**
# - **What is the price of the cheapest house?**
# - **What is the average number of bathrooms and bedrooms? round your answer to the lowest value**
# - **What is the maximum number of bedrooms?**

# %%
house_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# **PRACTICE OPPORTUNITY #2 SOLUTION:**
# - **Using Seaborn, plot the pairplot for the features contained in "house_df_sample"**
# - **Explore the data and perform sanity check**

# %%
sns.pairplot(house_df_sample)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-b30ddd2132e1> in <module>
# ----> 1 sns.pairplot(house_df_sample)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2096     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2097                     hue_order=hue_order, palette=palette, corner=corner,
# -> 2098                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2099
#    2100     # Add the markers here as PairGrid has figured out how many levels of the
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1244         axes = fig.subplots(len(y_vars), len(x_vars),
#    1245                             sharex="col", sharey="row",
# -> 1246                             squeeze=False)
#    1247
#    1248         # Possibly remove upper axes to make a corner grid
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1574                 subplot_kw["sharex"] = shared_with[sharex]
#    1575                 subplot_kw["sharey"] = shared_with[sharey]
# -> 1576                 axarr[row, col] = self.add_subplot(gs[row, col], **subplot_kw)
#    1577
#    1578         # turn off redundant tick labeling
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      74
#      75         # _axes_class is set in the subplot_class_factory
# ---> 76         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      77         # add a layout box to this, for both the full axis, and the poss
#      78         # of the axis.  We need both because the axes may become smaller
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     416         """
#     417
# --> 418         martist.Artist.__init__(self)
#     419         if isinstance(rect, mtransforms.Bbox):
#     420             self._position = rect
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in __init__(self)
#      96         self._propobservers = {}  # a dict from oids to funcs
#      97         try:
# ---> 98             self.axes = None
#      99         except AttributeError:
#     100             # Handle self.axes as a read-only property, as in Figure.
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in axes(self, new_axes)
#     195         return self._axes
#     196
# --> 197     @axes.setter
#     198     def axes(self, new_axes):
#     199         if (new_axes is not None and self._axes is not None
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f1cd7348710> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     125         for f_mgr in cls.get_all_fig_managers():
#     126             if force or f_mgr.canvas.figure.stale:
# --> 127                 f_mgr.canvas.draw_idle()
#     128
#     129 atexit.register(Gcf.destroy_all)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1945         if not self._is_idle_drawing:
#    1946             with self._idle_draw_cntx():
# -> 1947                 self.draw(*args, **kwargs)
#    1948
#    1949     @cbook.deprecated("3.2")
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     391              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     392               else nullcontext()):
# --> 393             self.figure.draw(self.renderer)
#     394             # A GUI class may be need to update a window using this draw, so
#     395             # don't forget to call the superclass.
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1227         ticks_to_draw = self._update_ticks()
#    1228         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1229                                                                 renderer)
#    1230
#    1231         for tick in ticks_to_draw:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1172         """Return lists of bboxes for ticks' label1's and label2's."""
#    1173         return ([tick.label1.get_window_extent(renderer)
# -> 1174                  for tick in ticks if tick.label1.get_visible()],
#    1175                 [tick.label2.get_window_extent(renderer)
#    1176                  for tick in ticks if tick.label2.get_visible()])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axis.py in <listcomp>(.0)
#    1172         """Return lists of bboxes for ticks' label1's and label2's."""
#    1173         return ([tick.label1.get_window_extent(renderer)
# -> 1174                  for tick in ticks if tick.label1.get_visible()],
#    1175                 [tick.label2.get_window_extent(renderer)
#    1176                  for tick in ticks if tick.label2.get_visible()])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     903             raise RuntimeError('Cannot get window extent w/o renderer')
#     904
# --> 905         bbox, info, descent = self._get_layout(self._renderer)
#     906         x, y = self.get_unitless_position()
#     907         x, y = self.get_transform().transform((x, y))
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py in _get_layout(self, renderer)
#     277         """
#     278         key = self.get_prop_tup(renderer=renderer)
# --> 279         if key in self._cached:
#     280             return self._cached[key]
#     281
#
# KeyboardInterrupt:

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 SOLUTION:**
# - **Change the architecture of the network by adding an additional dense layer with 200 neurons. Use "Relu" as an activation function**
# - **How many trainable parameters does the new network has**

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(100, input_dim = 7, activation = 'relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(1, activation = 'linear'))

model.summary()

# %% [markdown]
# **PRACTICE OPPORTUNITY #4 SOLUTION:**
# - **Change the architecture of the network to increase the coefficient of determination to at least 0.86.**

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(10, input_dim = 19, activation = 'relu'))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(200, activation = 'relu'))
model.add(Dense(200, activation = 'relu'))

model.add(Dense(1, activation = 'linear'))
